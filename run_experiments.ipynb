# %% [markdown]
# ## Clone Repo

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive
# Cloning into 'github.com'...
# fatal: repository 'https://github.com/' not found

# %%
# %cd /content/drive/MyDrive/
# !git clone https://github.com/mcmahonjosh/TreeOfThoughtsFinalProject
# Out:
# /content/drive/MyDrive
# Cloning into 'TreeOfThoughtsFinalProject'...
# remote: Enumerating objects: 128, done.
# remote: Counting objects: 100% (128/128), done.
# remote: Compressing objects: 100% (89/89), done.
# remote: Total 128 (delta 44), reused 107 (delta 29), pack-reused 0 (from 0)
# Receiving objects: 100% (128/128), 8.26 MiB | 8.95 MiB/s, done.
# Resolving deltas: 100% (44/44), done.
# Updating files: 100% (47/47), done.

# %%
# %cd /content/drive/MyDrive/TreeOfThoughtsFinalProject
# Out:
# /content/drive/MyDrive/TreeOfThoughtsFinalProject

# %% [markdown]
# ## Install Packages

# %%
# !pip install -r requirements.txt

# %%
# !pip install scikit-build-core
# Out:
# ...
#   Using cached scikit_build_core-0.12.2-py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached pathspec-1.1.1-py3-none-any.whl.metadata (14 kB)
# Using cached scikit_build_core-0.12.2-py3-none-any.whl (192 kB)
# Using cached pathspec-1.1.1-py3-none-any.whl (57 kB)
# ...

# %%
# !CMAKE_ARGS="-DLLAMA_CUDA=on" FORCE_CMAKE=1 pip install llama-cpp-python --no-cache-dir --force-reinstall --upgrade
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.0/68.0 MB 78.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 219.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 kB 288.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 261.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 168.5 MB/s eta 0:00:00
# ...
#   error: subprocess-exited-with-error
#
#   × Building wheel for llama-cpp-python (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for llama-cpp-python
# Failed to build llama-cpp-python
# ...

# %% [markdown]
# ## Run bash scripts for experiments

# %%
# !bash ./scripts/game24/standard_sampling.sh
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/TreeOfThoughtsFinalProject/run.py", line 6, in <module>
#     from tot.methods.bfs import solve, naive_solve
#   File "/content/drive/MyDrive/TreeOfThoughtsFinalProject/tot/methods/bfs.py", line 4, in <module>
#     from tot.models import qwen
#   File "/content/drive/MyDrive/TreeOfThoughtsFinalProject/tot/models.py", line 4, in <module>
#     from llama_cpp import Llama
# ModuleNotFoundError: No module named 'llama_cpp'
